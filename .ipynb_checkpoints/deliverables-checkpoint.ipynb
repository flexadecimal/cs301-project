# %%
import pandas as pd
import numpy as np
from itertools import chain
import matplotlib.pyplot as plot; plot.rcdefaults()
# for pretty printing dfs
from IPython.display import display

# %%
trials = pd.read_json('./dynomite_trials.json')
mods = pd.read_json('./dynomite_mods.json')
# replace mod numbers with human readable mods
mod_idx_name_dict = {
        '1':'boost', '2':'fuel',
        '3':'displacement', '4':'turbo_class',
        '5':'turbo_name', '7':'injection', '8':'nitrous',
        '9':'correction', '10':'heads',
        '11':'max_hp', '12':'max_tq'
};
# replace with human readable mods
readable_mods = [{mod_idx_name_dict[k]:v for k, v in r['mods'].items()} for idx, r in trials.iterrows()]
trials['mods'] = readable_mods
# split into hp/torque trials - make copies because we will add cols later
hp_trials = trials.copy().loc[trials['data_type_id'] == 1]
torque_trials = trials.copy().loc[trials['data_type_id'] == 2]
trials.head()
# Out:
#                   display_info                name           displayName  \
# 0  {'username': '11secondFWD'}  11secondFWD HP 9 1  11secondFWD HP (17g)
# 1  {'username': '11secondFWD'}  11secondFWD TQ 9 1  11secondFWD TQ (17g)
# 2      {'username': '2root4u'}     2root4u HP 18 1    2root4u HP (gt368)
# 3          {'username': '3sx'}          3sx HP 6 1         3sx HP (GT35)
# 4        {'username': '97vr4'}       97vr4 HP 15 1        97vr4 HP (19t)
#
#    owner_id  car_id  run_id  data_type_id  \
# 0         9       9       1             1
# 1         9       9       1             2
# 2        18      18       1             1
# 3         6       6       1             1
# 4        15      15       1             1
#
#                                                 mods  \
# 0       {'turbo_class': 'td04', 'turbo_name': '17g'}
# 1       {'turbo_class': 'td04', 'turbo_name': '17g'}
# 2  {'boost': '25', 'turbo_class': 'td04', 'turbo_...
# 3  {'turbo_class': 'td05', 'turbo_name': 'GT35', ...
# 4  {'boost': '25', 'turbo_class': 'td04', 'turbo_...
#
#                                             run_data
# 0  [{'x': 2510, 'y': 53}, {'x': 2921, 'y': 107}, ...
# 1  [{'x': 2514, 'y': 118}, {'x': 2619, 'y': 143},...
# 2  [{'x': 3564, 'y': 210}, {'x': 3942, 'y': 262},...
# 3  [{'x': 4200, 'y': 200}, {'x': 4800, 'y': 370},...
# 4  [{'x': 3457, 'y': 201}, {'x': 3686, 'y': 244},...

# %% [markdown]
# ## Supporting code - statistical functions

# %%
# regular 5-figure stats summary
def q_summary(numbers):
    # to calculate outliers
    quartiles = [np.quantile(numbers, 1/4), np.quantile(numbers, 2/4), np.quantile(numbers, 3/4)]
    IQR = 1.5*(quartiles[2]-quartiles[0])
    outliers = [n for n in numbers if (n < quartiles[0]-IQR or n > quartiles[2]+IQR)]
    withoutOutliers = [n for n in numbers if n not in outliers]
    # now print
    ret = {
        'min':np.min(withoutOutliers),
        'q1':quartiles[0],
        'q2':quartiles[1],
        'q3':quartiles[2],
        'max':np.max(withoutOutliers),
        'outliers':outliers if outliers else None
    }
    return ret

# 5-figure stats summary that can handle dataframe series as input and returns df rows
def q_summary_dataframe(df, col):
    numbers = df[col]
    # quartiles calculated as numbers
    quartiles = [np.quantile(numbers, 1/4), np.quantile(numbers, 2/4), np.quantile(numbers, 3/4)]
    IQR = 1.5*(quartiles[2]-quartiles[0])
    # outliers are rows, not single numbers now. you need bitwise OR for loc, it's weird
    outliers = df.loc[(df[col] < quartiles[0]-IQR) | (df[col] > quartiles[2]+IQR)]
    # bitwise NOT ~, i.e. rows not in outliers
    without_outliers = df[~df.isin(outliers)]
    # now print
    ret = {
        'min':without_outliers[without_outliers[col] == without_outliers[col].min()],
        # get rows that match quartiles
        'q1':without_outliers[without_outliers[col] == quartiles[0]],
        'q2':without_outliers[without_outliers[col] == quartiles[1]],
        'q3':without_outliers[without_outliers[col] == quartiles[2]],
        'max':without_outliers[without_outliers[col] == without_outliers[col].max()],
        'outliers': outliers
    }
    return ret

# pretty print 5-figure df summary
def print_df_summary(summary):
    field_to_name = {
        'min':'Minimum',
        'q1':'First quartile',
        'q2':'Mean',
        'q3':'Third quartile',
        'max':'Maximum',
        'outliers':'Outliers'
    }
    for field, name in field_to_name.items():
        if not summary[field].empty:
            print(name)
            display(summary[field])

# print out a 5-figure stats summary and return the integration bounds (median start and end rpm)
def summarize_trials_bounds(trials, name):
    start_rpms = [run[0]['x'] for run in trials] # only interested in 'x' part, i.e. rpm
    end_rpms = [run[-1]['x'] for run in trials]
    start_summary = q_summary(start_rpms)
    end_summary = q_summary(end_rpms)
    print('{} start RPM summary: {}'.format(name, start_summary))
    print('{} end RPM summary: {}'.format(name, end_summary))
    start = start_summary['q2']
    end = end_summary['q2']
    return (start, end)

# integrate run data [(x,y)...], filtering out values outside the [a,b] interval
def definite_discrete_integral(run, a, b):
    # filter out any data points with rpm less than a, greater than b
    filtered = [p for p in run if p['x'] >= a and p['x'] <= b]
    # discrete integral using trapezoidal rule
    xs = [p['x'] for p in filtered]
    ys = [p['y'] for p in filtered]
    return np.trapz(ys, x=xs)

# %% [markdown]
# ## Statistical summary on runs (integral as aggregate function)
# Run data has a different number of points for each run. 'outliers' is not a good question to ask without refinement because these are continous functions. We will do an outlier/min/max summary on the integral of each run, because a run with higher horsepower would have a bigger integral, which is what we are interested in.
#
# Runs have different start and end points (RPM), so we will take a median of start/end to use as the integration bounds.

# %%
integral_col_name = "total_power_normalized"

# for horsepower
hp_start, hp_end = summarize_trials_bounds(hp_trials['run_data'], 'horsepower')
print('Integration bounds (median q2): ({}, {})'.format(hp_start, hp_end), end='\n\n')
# now do the integrals and add to dataframe
hp_trials[integral_col_name] = hp_trials['run_data'].apply(lambda r: definite_discrete_integral(r, hp_start, hp_end))
hp_trials.head()
# Out:
# horsepower start RPM summary: {'min': 1020, 'q1': 2510.0, 'q2': 3065.0, 'q3': 3603.0, 'max': 4672, 'outliers': None}
# horsepower end RPM summary: {'min': 5988, 'q1': 6639.0, 'q2': 6965.0, 'q3': 7158.0, 'max': 7544, 'outliers': [8500, 7950, 8011, 8463, 8468, 8072, 8015]}
# Integration bounds (median q2): (3065.0, 6965.0)
#                   display_info                name            displayName  \
# 0  {'username': '11secondFWD'}  11secondFWD HP 9 1   11secondFWD HP (17g)
# 2      {'username': '2root4u'}     2root4u HP 18 1     2root4u HP (gt368)
# 3          {'username': '3sx'}          3sx HP 6 1          3sx HP (GT35)
# 4        {'username': '97vr4'}       97vr4 HP 15 1         97vr4 HP (19t)
# 5      {'username': 'AdamVR4'}      AdamVR4 HP 8 1  AdamVR4 HP (evo3 16g)
#
#    owner_id  car_id  run_id  data_type_id  \
# 0         9       9       1             1
# 2        18      18       1             1
# 3         6       6       1             1
# 4        15      15       1             1
# 5         8       8       1             1
#
#                                                 mods  \
# 0       {'turbo_class': 'td04', 'turbo_name': '17g'}
# 2  {'boost': '25', 'turbo_class': 'td04', 'turbo_...
# 3  {'turbo_class': 'td05', 'turbo_name': 'GT35', ...
# 4  {'boost': '25', 'turbo_class': 'td04', 'turbo_...
# 5  {'boost': '30', 'fuel': 'race', 'turbo_class':...
#
#                                             run_data  total_power_normalized
# 0  [{'x': 2510, 'y': 53}, {'x': 2921, 'y': 107}, ...               1023050.0
# 2  [{'x': 3564, 'y': 210}, {'x': 3942, 'y': 262},...               1354755.0
# 3  [{'x': 4200, 'y': 200}, {'x': 4800, 'y': 370},...               1579750.0
# 4  [{'x': 3457, 'y': 201}, {'x': 3686, 'y': 244},...               1820158.0
# 5  [{'x': 3166, 'y': 144}, {'x': 3516, 'y': 189},...               1308968.5

# %%
# 5-stat summary on the hp integrals
hp_integral_summary = q_summary_dataframe(hp_trials, integral_col_name)
print_df_summary(hp_integral_summary)
# Out:
# Minimum
#                     display_info                  name            displayName  \
# 49  {'username': 'levani041491'}  levani041491 HP 51 1  levani041491 HP (13t)
#
#     owner_id  car_id  run_id  data_type_id  \
# 49      47.0    51.0     1.0           1.0
#
#                                                  mods  \
# 49  {'boost': '8', 'turbo_class': 'td04', 'turbo_n...
#
#                                              run_data  total_power_normalized
# 49  [{'x': 2483, 'y': 103}, {'x': 3030, 'y': 155},...                747638.0
# First quartile
#                  display_info               name  \
# 57  {'username': 'niteryder'}  niteryder HP 35 1
#
#                       displayName  owner_id  car_id  run_id  data_type_id  \
# 57  niteryder HP (twim 50trim bb)      33.0    35.0     1.0           1.0
#
#                                                  mods  \
# 57  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized
# 57  [{'x': 4503, 'y': 205}, {'x': 4716, 'y': 235},...               1164535.5
# Mean
#                    display_info                 name  \
# 72  {'username': 'Ray Pampena'}  Ray Pampena HP 15 2
#
#                       displayName  owner_id  car_id  run_id  data_type_id  \
# 72  Ray Pampena HP (dr650 billet)      14.0    15.0     2.0           1.0
#
#                                                  mods  \
# 72  {'boost': '19', 'fuel': 'pump', 'turbo_class':...
#
#                                              run_data  total_power_normalized
# 72  [{'x': 2493, 'y': 117}, {'x': 2948, 'y': 181},...               1377093.5
# Third quartile
#                         display_info                      name  \
# 22  {'username': 'HillbillyHomeboy'}  HillbillyHomeboy HP 37 1
#
#                      displayName  owner_id  car_id  run_id  data_type_id  \
# 22  HillbillyHomeboy HP (GT3076)      34.0    37.0     1.0           1.0
#
#                                                  mods  \
# 22  {'boost': '31', 'turbo_class': 'td05', 'turbo_...
#
#                                              run_data  total_power_normalized
# 22  [{'x': 3923, 'y': 211}, {'x': 4049, 'y': 242},...               1669246.0
# Maximum
#               display_info            name           displayName  owner_id  \
# 97  {'username': 'Trevor'}  Trevor HP 42 2  Trevor HP (GTX4202R)      39.0
#
#     car_id  run_id  data_type_id  \
# 97    42.0     2.0           1.0
#
#                                                  mods  \
# 97  {'boost': '33.1', 'fuel': 'e85', 'displacement...
#
#                                              run_data  total_power_normalized
# 97  [{'x': 2536, 'y': 106}, {'x': 2828, 'y': 130},...               2375776.5
# Outliers
#              display_info          name             displayName  owner_id  \
# 35  {'username': 'JRink'}  JRink HP 5 2  JRink HP (mtc stage 4)         5
#
#     car_id  run_id  data_type_id  \
# 35       5       2             1
#
#                                                  mods  \
# 35  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized
# 35  [{'x': 3300, 'y': 202}, {'x': 3400, 'y': 222},...               2482500.0

# %%
# for torque
torque_start, torque_end = summarize_trials_bounds(torque_trials['run_data'], 'torque')
print('Integration bounds (median q2): ({}, {})'.format(torque_start, torque_end))
torque_trials[integral_col_name] = torque_trials['run_data'].apply(lambda r: definite_discrete_integral(r, torque_start, torque_end))
torque_trials.head()
# Out:
# torque start RPM summary: {'min': 1916, 'q1': 2400.0, 'q2': 2536.0, 'q3': 2882.0, 'max': 3300, 'outliers': [1012]}
# torque end RPM summary: {'min': 6399, 'q1': 6758.0, 'q2': 6961.0, 'q3': 7100.0, 'max': 7563, 'outliers': [7950, 6103]}
# Integration bounds (median q2): (2536.0, 6961.0)
#                    display_info                name  \
# 1   {'username': '11secondFWD'}  11secondFWD TQ 9 1
# 6       {'username': 'AdamVR4'}      AdamVR4 TQ 8 1
# 8       {'username': 'BaadVR4'}     BaadVR4 TQ 12 1
# 11  {'username': 'boostaddict'}  boostaddict TQ 2 1
# 16   {'username': 'chansigril'}  chansigril TQ 48 1
#
#                   displayName  owner_id  car_id  run_id  data_type_id  \
# 1        11secondFWD TQ (17g)         9       9       1             2
# 6       AdamVR4 TQ (evo3 16g)         8       8       1             2
# 8       BaadVR4 TQ (evo3 16g)        12      12       1             2
# 11  boostaddict TQ (evo3 16g)         2       2       1             2
# 16        chansigril TQ (13t)        44      48       1             2
#
#                                                  mods  \
# 1        {'turbo_class': 'td04', 'turbo_name': '17g'}
# 6   {'boost': '30', 'fuel': 'race', 'turbo_class':...
# 8   {'boost': '24', 'fuel': 'pump', 'turbo_class':...
# 11  {'boost': '36', 'fuel': 'race', 'displacement'...
# 16       {'turbo_class': 'td04', 'turbo_name': '13t'}
#
#                                              run_data  total_power_normalized
# 1   [{'x': 2514, 'y': 118}, {'x': 2619, 'y': 143},...               1290045.0
# 6   [{'x': 3160, 'y': 232}, {'x': 3298, 'y': 252},...               1422245.5
# 8   [{'x': 2856, 'y': 226}, {'x': 3339, 'y': 283},...               1781925.5
# 11  [{'x': 2850, 'y': 176}, {'x': 2900, 'y': 180},...               1913475.0
# 16  [{'x': 2495, 'y': 159}, {'x': 2521, 'y': 296},...               1686407.0

# %%
# 5-stat summary on the torque integrals
torque_integral_summary = q_summary_dataframe(torque_trials, integral_col_name)
print_df_summary(torque_integral_summary)
# Out:
# Minimum
#                 display_info              name       displayName  owner_id  \
# 31  {'username': 'J-Groove'}  J-Groove TQ 45 1  J-Groove TQ (9b)        42
#
#     car_id  run_id  data_type_id  \
# 31      45       1             2
#
#                                                  mods  \
# 31  {'boost': '12', 'fuel': 'pump', 'displacement'...
#
#                                              run_data  total_power_normalized
# 31  [{'x': 2525, 'y': 216}, {'x': 2941, 'y': 256},...                924178.5
# First quartile
#                display_info             name            displayName  owner_id  \
# 28  {'username': 'Intropy'}  Intropy TQ 11 1  Intropy TQ (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 28      11       1             2
#
#                                                  mods  \
# 28  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized
# 28  [{'x': 3112, 'y': 205}, {'x': 3328, 'y': 228},...               1487767.5
# Mean
#                    display_info                 name             displayName  \
# 67  {'username': 'Ray Pampena'}  Ray Pampena TQ 14 2  Ray Pampena TQ (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 67        14      14       2             2
#
#                                                  mods  \
# 67  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized
# 67  [{'x': 2493, 'y': 211}, {'x': 2679, 'y': 233},...               1643524.5
# Third quartile
#              display_info          name             displayName  owner_id  \
# 34  {'username': 'JRink'}  JRink TQ 5 1  JRink TQ (mtc stage 4)         5
#
#     car_id  run_id  data_type_id  \
# 34       5       1             2
#
#                                                  mods  \
# 34  {'fuel': 'pump', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized
# 34  [{'x': 3100, 'y': 291}, {'x': 3200, 'y': 306},...               2022550.0
# Maximum
#              display_info          name          displayName  owner_id  \
# 46  {'username': 'JRink'}  JRink TQ 5 7  JRink TQ (fp 68hta)         5
#
#     car_id  run_id  data_type_id  \
# 46       5       7             2
#
#                                                  mods  \
# 46  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized
# 46  [{'x': 2600, 'y': 173}, {'x': 2700, 'y': 212},...               2561250.0

# %% [markdown]
# ## Supporting code - filter out trials by mods

# %%
# filter trials by acceptable mods. acceptable mods is specified by a dictionary of modname:[acceptable values],
# e.g. {'heads':['stock', None], 'injection':[None]}.
# references mod_idx_name_dict global from above!
def filter_by_mods(trials, mods_spec):
    # to specifiy range of numbers rather than discrete list
    numeric_mods = ['boost', 'displacement', 'max_hp', 'max_tq']
    filtered = []
    for idx, r in trials.iterrows():
        # for ease of comparison, convert unspecified mods to None...
        mods_withnull = {mod:r['mods'][mod] if mod in r['mods'] else None for k, mod in mod_idx_name_dict.items()}
        # ...so we can just check if the value is in the acceptable values
        filter_results = []
        for mod, vals in mods_spec.items():
            if mod in numeric_mods and mods_withnull[mod] is not None:
                numeric_val = float(mods_withnull[mod])
                start = vals[0]
                end = vals[1]
                filter_results.append(numeric_val >= start and numeric_val <= end)
            else:
                filter_results.append(mods_withnull[mod] in vals)
        # row is filtered if none of the conditions were false i.e. all specifications matched
        if False not in filter_results:
            filtered.append(r)
    return pd.DataFrame(filtered)

# example: numeric range
# boost_spec = {
#     'boost':(10, 30)
# }
# display(filter_by_mods(hp_trials, boost_spec))

# example: stock engine trials
# stockengine_spec = {
#     'injection':[None],
#     'nitrous':[None],
#     'heads':['stock', None]
# }
# display(filter_by_mods(hp_trials, stockengine_spec))

# %% [markdown]
# ## Question 1 - Best 1/8th, 1/2 mile
# *Which run would be fastest in an 1/8th or 1/2 mile drag race?*
#
# Drag races take place over 1/8th, 1/4, and 1/2 mile drag strips. 1/8 mile times are usually around 7 seconds - which means that the most important part of a drag race is right off the line. This means that we want the most "pull" off the line, i.e. the most torque.
#
# The difference between 1/8th and 1/2 mile in this case is in what RPM range we care about - in the shorter 1/8th mile, you do not have the time to reach a higher RPM. So, for our project, we will define the ranges by statistial summary:
#
# 1/8th mile: [median start RPM, 4000]
#
# 1/2 mile: [median start RPM, 7000]
#
# For each range, to find the best hypothetical drag car:
# - **Calculate the total force for each torque run** by taking the integral on the specified bounds.
# - Sort by the calculated total force, highest to lowest. **1st run will be the highest total force in the "off the line" RPM range**.

# %%
# seperate copies for 1/8th, 1/2 mile
tq_trials_eighth = torque_trials.copy()
tq_trials_half = torque_trials.copy()
# get bounds
eighth_bounds = (summarize_trials_bounds(tq_trials_eighth['run_data'], 'torque')[0], 4000)
half_bounds = (summarize_trials_bounds(tq_trials_half['run_data'], 'torque')[0], 7000)
# calculate 'off the line' power for each
tq_trials_eighth['off_the_line'] = tq_trials_eighth['run_data'].apply(lambda r: definite_discrete_integral(r, eighth_bounds[0], eighth_bounds[1]))
tq_trials_half['off_the_line'] = tq_trials_half['run_data'].apply(lambda r: definite_discrete_integral(r, half_bounds[0], half_bounds[1]))
# Out:
# torque start RPM summary: {'min': 1916, 'q1': 2400.0, 'q2': 2536.0, 'q3': 2882.0, 'max': 3300, 'outliers': [1012]}
# torque end RPM summary: {'min': 6399, 'q1': 6758.0, 'q2': 6961.0, 'q3': 7100.0, 'max': 7563, 'outliers': [7950, 6103]}
# torque start RPM summary: {'min': 1916, 'q1': 2400.0, 'q2': 2536.0, 'q3': 2882.0, 'max': 3300, 'outliers': [1012]}
# torque end RPM summary: {'min': 6399, 'q1': 6758.0, 'q2': 6961.0, 'q3': 7100.0, 'max': 7563, 'outliers': [7950, 6103]}

# %% [markdown]
# ### 1/2 mile

# %%
num_top = 5
top = tq_trials_half.sort_values(by='off_the_line', ascending=False).head(num_top)
print_df_summary(q_summary_dataframe(top, 'off_the_line'))
# Out:
# Minimum
#               display_info            name           displayName  owner_id  \
# 98  {'username': 'Trevor'}  Trevor TQ 42 2  Trevor TQ (GTX4202R)        39
#
#     car_id  run_id  data_type_id  \
# 98      42       2             2
#
#                                                  mods  \
# 98  {'boost': '33.1', 'fuel': 'e85', 'displacement...
#
#                                              run_data  total_power_normalized  \
# 98  [{'x': 2536, 'y': 222}, {'x': 2762, 'y': 241},...               2471290.5
#
#     off_the_line
# 98     2471290.5
# First quartile
#              display_info          name             displayName  owner_id  \
# 38  {'username': 'JRink'}  JRink TQ 5 3  JRink TQ (MTC Stage 2)         5
#
#     car_id  run_id  data_type_id  \
# 38       5       3             2
#
#                                                  mods  \
# 38  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 38  [{'x': 2300, 'y': 154}, {'x': 2400, 'y': 177},...               2436300.0
#
#     off_the_line
# 38     2490350.0
# Mean
#              display_info          name          displayName  owner_id  \
# 42  {'username': 'JRink'}  JRink TQ 5 5  JRink TQ (evo3 16g)         5
#
#     car_id  run_id  data_type_id  \
# 42       5       5             2
#
#                                                  mods  \
# 42  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 42  [{'x': 2400, 'y': 105}, {'x': 2500, 'y': 184},...               2459600.0
#
#     off_the_line
# 42     2511050.0
# Third quartile
#              display_info          name             displayName  owner_id  \
# 36  {'username': 'JRink'}  JRink TQ 5 2  JRink TQ (mtc stage 4)         5
#
#     car_id  run_id  data_type_id  \
# 36       5       2             2
#
#                                                  mods  \
# 36  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 36  [{'x': 3300, 'y': 321}, {'x': 3400, 'y': 344},...               2477200.0
#
#     off_the_line
# 36     2542950.0
# Maximum
#              display_info          name          displayName  owner_id  \
# 46  {'username': 'JRink'}  JRink TQ 5 7  JRink TQ (fp 68hta)         5
#
#     car_id  run_id  data_type_id  \
# 46       5       7             2
#
#                                                  mods  \
# 46  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 46  [{'x': 2600, 'y': 173}, {'x': 2700, 'y': 212},...               2561250.0
#
#     off_the_line
# 46     2613000.0

# %%
torque = [r['off_the_line'] for idx, r in top.iterrows()]
run = [r['name'] for idx, r in top.iterrows()]
y = np.arange(len(run))
plot.bar(y, torque, align = 'center', alpha = .7)
plot.xticks(y, run, rotation=35)
plot.ylabel('Total force (N)')
plot.xlabel('Run name')
plot.axis([-1,len(run), 2450000, 2625000])
plot.title('Off The Line Power ({} to {} RPM)'.format(half_bounds[0], half_bounds[1]))
plot.gcf().set_size_inches(12, 6)
plot.show()

# %% [markdown]
# ### 1/8th mile

# %%
num_top = 5
top = tq_trials_eighth.sort_values(by='off_the_line', ascending=False).head(num_top)
print_df_summary(q_summary_dataframe(top, 'off_the_line'))
# Out:
# Minimum
#                 display_info             name         displayName  owner_id  \
# 106  {'username': 'TT Eric'}  TT Eric TQ 13 1  TT Eric TQ (dr750)      13.0
#
#      car_id  run_id  data_type_id  \
# 106    13.0     1.0           2.0
#
#                                                   mods  \
# 106  {'boost': '30', 'displacement': '3.0', 'turbo_...
#
#                                               run_data  \
# 106  [{'x': 2287, 'y': 215}, {'x': 2486, 'y': 241},...
#
#      total_power_normalized  off_the_line
# 106               2258577.0      600150.5
# First quartile
#                 display_info             name         displayName  owner_id  \
# 106  {'username': 'TT Eric'}  TT Eric TQ 13 1  TT Eric TQ (dr750)      13.0
#
#      car_id  run_id  data_type_id  \
# 106    13.0     1.0           2.0
#
#                                                   mods  \
# 106  {'boost': '30', 'displacement': '3.0', 'turbo_...
#
#                                               run_data  \
# 106  [{'x': 2287, 'y': 215}, {'x': 2486, 'y': 241},...
#
#      total_power_normalized  off_the_line
# 106               2258577.0      600150.5
# Mean
#                   display_info                name          displayName  \
# 16  {'username': 'chansigril'}  chansigril TQ 48 1  chansigril TQ (13t)
#
#     owner_id  car_id  run_id  data_type_id  \
# 16      44.0    48.0     1.0           2.0
#
#                                             mods  \
# 16  {'turbo_class': 'td04', 'turbo_name': '13t'}
#
#                                              run_data  total_power_normalized  \
# 16  [{'x': 2495, 'y': 159}, {'x': 2521, 'y': 296},...               1686407.0
#
#     off_the_line
# 16      608673.5
# Third quartile
#              display_info          name          displayName  owner_id  \
# 42  {'username': 'JRink'}  JRink TQ 5 5  JRink TQ (evo3 16g)       5.0
#
#     car_id  run_id  data_type_id  \
# 42     5.0     5.0           2.0
#
#                                                  mods  \
# 42  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 42  [{'x': 2400, 'y': 105}, {'x': 2500, 'y': 184},...               2459600.0
#
#     off_the_line
# 42      612600.0
# Maximum
#              display_info          name          displayName  owner_id  \
# 40  {'username': 'JRink'}  JRink TQ 5 4  JRink TQ (evo3 16g)       5.0
#
#     car_id  run_id  data_type_id  \
# 40     5.0     4.0           2.0
#
#                                                  mods  \
# 40  {'fuel': 'pump', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 40  [{'x': 2200, 'y': 156}, {'x': 2300, 'y': 193},...               2268050.0
#
#     off_the_line
# 40      616850.0
# Outliers
#              display_info          name          displayName  owner_id  \
# 46  {'username': 'JRink'}  JRink TQ 5 7  JRink TQ (fp 68hta)         5
#
#     car_id  run_id  data_type_id  \
# 46       5       7             2
#
#                                                  mods  \
# 46  {'fuel': 'race', 'turbo_class': 'td05', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 46  [{'x': 2600, 'y': 173}, {'x': 2700, 'y': 212},...               2561250.0
#
#     off_the_line
# 46      572400.0

# %%
torque = [r['off_the_line'] for idx, r in top.iterrows()]
run = [r['name'] for idx, r in top.iterrows()]
y = np.arange(len(run))
plot.bar(y, torque, align = 'center', alpha = .7)
plot.xticks(y, run, rotation=35)
plot.ylabel('Total force (N)')
plot.xlabel('Run name')
plot.axis([-1,len(run), 560000, 620000])
plot.title('Off The Line Power ({} to {} RPM)'.format(eighth_bounds[0], eighth_bounds[1]))
plot.gcf().set_size_inches(12, 6)
plot.show()

# %% [markdown]
# ## Question 2 - "Bang for the Buck" fuel
# *Which of the different types of fuel (pump gas, e85 ethanol fuel, 100 octane race fuel) provides the most power versus cost?*

# %% [markdown]
# Total power over each run has been calculated. For a fair comparison, filter out horsepower runs with:
# - **stock engine** (stock heads, no methylene injection or nitrous)
# - **same boost level** (either naturally aspirated/no turbo (0 boost) or most common, e.g. 20 psi - more boost means more power)
# - **similar displacement** higher displacement means more power. Filter by similar ranges, e.g. [3.0, 3.1] or [3.5, 3.7].
#
# ...then group by the fuel type. For each group, find the ratio of total power over fuel cost per gallon. The highest ratio will be the most powerful fuel per dollar. See the first deliverable for links to fuel prices.

# %%
gas_prices = {
    'pump':2.03,
    'race':13.11,
    'e85':1.83,
    # ed95 is ethanol diesel fuel, not commonly used - think e85, but for diesel cars. used in buses, etc.
    # because of its rarity, it is not commercially available - regular diesel price of $3/gal subsituted here.
    'e95m5':3.00
}
# boost level/displacement should not be too restrictive.
similar_boost_displacement_spec = {
    'boost':(10, 25),
    'heads':['stock', None],
    'injection':[None],
    'nitrous':[None],
    'displacement':(3.0, 3.3)
}
similar_boost_displacement = filter_by_mods(hp_trials, similar_boost_displacement_spec)
# calculate total power to fuel cost ratio for each trial
# if fuel is not specified, assume pump gas (which is a reasonable assumption!)
def power_cost_ratio(r):
    if 'fuel' in r['mods']:
        return r['total_power_normalized']/gas_prices[r['mods']['fuel']]
    else:
        return r['total_power_normalized']/gas_prices['pump']

power_cost_ratios = [power_cost_ratio(r) for idx, r in similar_boost_displacement.iterrows()]
similar_boost_displacement['power_fuelcost_ratio'] = power_cost_ratios
# split out fuel type as column so we can group by fuel type, again with default pump gas assumption
fuel_types = [r['mods']['fuel'] if 'fuel' in r['mods'] else 'pump' for idx, r in similar_boost_displacement.iterrows()]
similar_boost_displacement['fuel_type'] = fuel_types
# now group by fuel and show aggregate
fuel_grouped = {name:data for name, data in similar_boost_displacement.groupby('fuel_type')}

# %% [markdown]
# ### stats by fuel type

# %%
for fuel in gas_prices.keys():
    if fuel in fuel_grouped.keys():
        print("Stats for {} fuel".format(fuel))
        print_df_summary(q_summary_dataframe(fuel_grouped[fuel], 'power_fuelcost_ratio'))
# Out:
# Stats for pump fuel
# Minimum
#                 display_info              name       displayName  owner_id  \
# 30  {'username': 'J-Groove'}  J-Groove HP 45 1  J-Groove HP (9b)        42
#
#     car_id  run_id  data_type_id  \
# 30      45       1             1
#
#                                                  mods  \
# 30  {'boost': '12', 'fuel': 'pump', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 30  [{'x': 2505, 'y': 103}, {'x': 2993, 'y': 153},...                779350.0
#
#     power_fuelcost_ratio fuel_type
# 30         383916.256158      pump
# Mean
#                    display_info                 name             displayName  \
# 64  {'username': 'Ray Pampena'}  Ray Pampena HP 14 1  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 64        14      14       1             1
#
#                                                  mods  \
# 64  {'boost': '19', 'fuel': 'pump', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 64  [{'x': 2872, 'y': 149}, {'x': 3460, 'y': 237},...               1271356.0
#
#     power_fuelcost_ratio fuel_type
# 64         626283.743842      pump
# Maximum
#             display_info         name    displayName  owner_id  car_id  \
# 92  {'username': 'toni'}  toni HP 1 2  toni HP (15g)         1       1
#
#     run_id  data_type_id                                               mods  \
# 92       2             1  {'boost': '17', 'displacement': '3.0', 'turbo_...
#
#                                              run_data  total_power_normalized  \
# 92  [{'x': 2500, 'y': 54}, {'x': 2600, 'y': 88}, {...               1284700.0
#
#     power_fuelcost_ratio fuel_type
# 92         632857.142857      pump
# Stats for race fuel
# Minimum
#                    display_info                 name             displayName  \
# 66  {'username': 'Ray Pampena'}  Ray Pampena HP 14 2  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 66        14      14       2             1
#
#                                                  mods  \
# 66  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 66  [{'x': 2472, 'y': 99}, {'x': 2705, 'y': 121}, ...               1389398.5
#
#     power_fuelcost_ratio fuel_type
# 66         105980.053394      race
# First quartile
#                    display_info                 name             displayName  \
# 66  {'username': 'Ray Pampena'}  Ray Pampena HP 14 2  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 66        14      14       2             1
#
#                                                  mods  \
# 66  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 66  [{'x': 2472, 'y': 99}, {'x': 2705, 'y': 121}, ...               1389398.5
#
#     power_fuelcost_ratio fuel_type
# 66         105980.053394      race
# Mean
#                    display_info                 name             displayName  \
# 66  {'username': 'Ray Pampena'}  Ray Pampena HP 14 2  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 66        14      14       2             1
#
#                                                  mods  \
# 66  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 66  [{'x': 2472, 'y': 99}, {'x': 2705, 'y': 121}, ...               1389398.5
#
#     power_fuelcost_ratio fuel_type
# 66         105980.053394      race
# Third quartile
#                    display_info                 name             displayName  \
# 66  {'username': 'Ray Pampena'}  Ray Pampena HP 14 2  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 66        14      14       2             1
#
#                                                  mods  \
# 66  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 66  [{'x': 2472, 'y': 99}, {'x': 2705, 'y': 121}, ...               1389398.5
#
#     power_fuelcost_ratio fuel_type
# 66         105980.053394      race
# Maximum
#                    display_info                 name             displayName  \
# 66  {'username': 'Ray Pampena'}  Ray Pampena HP 14 2  Ray Pampena HP (dr650)
#
#     owner_id  car_id  run_id  data_type_id  \
# 66        14      14       2             1
#
#                                                  mods  \
# 66  {'boost': '25', 'fuel': 'race', 'displacement'...
#
#                                              run_data  total_power_normalized  \
# 66  [{'x': 2472, 'y': 99}, {'x': 2705, 'y': 121}, ...               1389398.5
#
#     power_fuelcost_ratio fuel_type
# 66         105980.053394      race
# Stats for e85 fuel
# Minimum
#                display_info             name            displayName  owner_id  \
# 27  {'username': 'Intropy'}  Intropy HP 11 1  Intropy HP (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 27      11       1             1
#
#                                                  mods  \
# 27  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized  \
# 27  [{'x': 3065, 'y': 96}, {'x': 3324, 'y': 125}, ...               1409773.5
#
#     power_fuelcost_ratio fuel_type
# 27         770368.032787       e85
# First quartile
#                display_info             name            displayName  owner_id  \
# 27  {'username': 'Intropy'}  Intropy HP 11 1  Intropy HP (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 27      11       1             1
#
#                                                  mods  \
# 27  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized  \
# 27  [{'x': 3065, 'y': 96}, {'x': 3324, 'y': 125}, ...               1409773.5
#
#     power_fuelcost_ratio fuel_type
# 27         770368.032787       e85
# Mean
#                display_info             name            displayName  owner_id  \
# 27  {'username': 'Intropy'}  Intropy HP 11 1  Intropy HP (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 27      11       1             1
#
#                                                  mods  \
# 27  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized  \
# 27  [{'x': 3065, 'y': 96}, {'x': 3324, 'y': 125}, ...               1409773.5
#
#     power_fuelcost_ratio fuel_type
# 27         770368.032787       e85
# Third quartile
#                display_info             name            displayName  owner_id  \
# 27  {'username': 'Intropy'}  Intropy HP 11 1  Intropy HP (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 27      11       1             1
#
#                                                  mods  \
# 27  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized  \
# 27  [{'x': 3065, 'y': 96}, {'x': 3324, 'y': 125}, ...               1409773.5
#
#     power_fuelcost_ratio fuel_type
# 27         770368.032787       e85
# Maximum
#                display_info             name            displayName  owner_id  \
# 27  {'username': 'Intropy'}  Intropy HP 11 1  Intropy HP (evo3 16g)        11
#
#     car_id  run_id  data_type_id  \
# 27      11       1             1
#
#                                                  mods  \
# 27  {'boost': '18', 'fuel': 'e85', 'displacement':...
#
#                                              run_data  total_power_normalized  \
# 27  [{'x': 3065, 'y': 96}, {'x': 3324, 'y': 125}, ...               1409773.5
#
#     power_fuelcost_ratio fuel_type
# 27         770368.032787       e85

# %%
mean_ratios = similar_boost_displacement.groupby('fuel_type')['power_fuelcost_ratio'].mean().reset_index() 
# for labels
median_label_locs = np.arange(mean_ratios.shape[0])
# plot the data
w = 0.5
# - median midterm
plot.bar(median_label_locs, mean_ratios['power_fuelcost_ratio'], width=w)

# title, labels, legend
plot.title('Fuel Type vs. Mean Total Power/Fuel Cost')
plot.ylabel('Total power (N)/Fuel Cost ($/gal)')
plot.xlabel('Fuel Type')
plot.xticks(median_label_locs, mean_ratios['fuel_type'])
# show
plot.gcf().set_size_inches(12, 6)
plot.show()

# %% [markdown]
# ## Question 3 - Top 10 Turbocharger Comparison
# *Which of the 10 most popular turbochargers has the least lag?*
#
# Turbochager lag is the "bump" in power delivery when boost kicks in. Looking at dyno charts, you can intuitively see the lag as those runs where.
#
# The following function calculates the gradient for a run, i.e a list of the discrete derivatives between each point.

# %%
def discrete_gradient(run_data):
    run_x = [p['x'] for p in run_data]
    run_y = [p['y'] for p in run_data]
    return list(np.gradient(run_y, run_x))

# %% [markdown]
# In the example, the first element of the gradient is the difference between the first 2 points - so overall, if the run has *n* points, the gradient has *n-1* points. Remember - a negative number in the gradient describes a decrease in power.
#
# The max element in the gradient is the maximum 'jump' - the max of the gradient for each comparable run will be the quantitative measure of turbo lag.

# %%
# example of gradient for a single run
print_n_el = 5
run = hp_trials.iloc[0]['run_data']
print('Run data: {}...'.format(run[:print_n_el]))
print('Run gradient: {}...'.format(discrete_gradient(run)[:print_n_el]))
print('Max jump: {}'.format(max(discrete_gradient(run))))
# Out:
# Run data: [{'x': 2510, 'y': 53}, {'x': 2921, 'y': 107}, {'x': 2976, 'y': 109}, {'x': 3866, 'y': 214}, {'x': 4160, 'y': 257}]...
# Run gradient: [0.13138686131386862, 0.0475788238577628, 0.04111365122601076, 0.13923603149124808, 0.16683480896161063]...
# Max jump: 0.16683480896161063

# %% [markdown]
# So, to find the top 10 turbos by lag:
# - **filter by same turbo class** - turbos are comparable by class - td03 turbo and td04 turbo is not a fair comparison.
# - **filter by similar mods** (same heads, similar displacement)
# - **find the max of the gradient for each run**
# - **sort from least to highest max gradient value**, then take the top 10 **unique** turbos from the runs.

# %%
# calculate the 'max jump' i.e. biggest bump in horsepower for each trial
max_gradients = [max(discrete_gradient(r['run_data'])) for idx, r in hp_trials.iterrows()]
hp_trials_copy = hp_trials.copy()
hp_trials_copy['max_jump'] = max_gradients
# filter to stock engine specs for fair turbo comparison
stockengine_spec = {
    'injection':[None],
    'nitrous':[None],
    'heads':['stock', None]
}
stock_engine = filter_by_mods(hp_trials_copy, stockengine_spec)
# filter by turbo classes t4, td04, td05 for fair comparison in each class
t4 = filter_by_mods(stock_engine, {'turbo_class':['t4']}) # no t4 turbos in our data set!
td04 = filter_by_mods(stock_engine, {'turbo_class':['td04']})
td05 = filter_by_mods(stock_engine, {'turbo_class':['td05']})
# report for each class: get turbo name as column so we can group by turbo...

# %% [markdown]
# ### TD04

# %%
td04_turbos = [r['mods']['turbo_name'] for idx, r in td04.iterrows()]
td04['turbo'] = td04_turbos
td04_avg_maxlag = td04.groupby('turbo')['max_jump'].mean().reset_index().sort_values(by='max_jump')
# top 10
top = 10
print('Top 10 td04 turbos:')
display(td04_avg_maxlag.head(top))
# stats
print_df_summary(q_summary_dataframe(td04, 'max_jump'))
# Out:
# Top 10 td04 turbos:
#        turbo  max_jump
# 5         9b  0.100383
# 11     gt357  0.102240
# 0        13g  0.122219
# 6      dr500  0.141276
# 13  phantoms  0.148665
# 3        17g  0.166835
# 7      dr650  0.178770
# 12     gt368  0.217312
# 2        15g  0.217860
# 9     dr650r  0.286557
# Minimum
#                  display_info               name         displayName  \
# 59  {'username': 'NOMIEZVR4'}  NOMIEZVR4 HP 10 1  NOMIEZVR4 HP (19t)
#
#     owner_id  car_id  run_id  data_type_id  \
# 59      10.0    10.0     1.0           1.0
#
#                                                  mods  \
# 59  {'boost': '15', 'turbo_class': 'td04', 'turbo_...
#
#                                              run_data  total_power_normalized  \
# 59  [{'x': 3222, 'y': 193}, {'x': 3344, 'y': 201},...               1255726.0
#
#     max_jump turbo
# 59  0.084051   19t
# First quartile
#              display_info           name          displayName  owner_id  \
# 88  {'username': 'spfan'}  spfan HP 21 1  spfan HP (phantoms)      21.0
#
#     car_id  run_id  data_type_id  \
# 88    21.0     1.0           1.0
#
#                                                  mods  \
# 88  {'boost': '21', 'fuel': 'race', 'turbo_class':...
#
#                                              run_data  total_power_normalized  \
# 88  [{'x': 3851, 'y': 217}, {'x': 4111, 'y': 255},...                958768.5
#
#     max_jump     turbo
# 88  0.148665  phantoms
# Mean
#                    display_info                 name  \
# 72  {'username': 'Ray Pampena'}  Ray Pampena HP 15 2
#
#                       displayName  owner_id  car_id  run_id  data_type_id  \
# 72  Ray Pampena HP (dr650 billet)      14.0    15.0     2.0           1.0
#
#                                                  mods  \
# 72  {'boost': '19', 'fuel': 'pump', 'turbo_class':...
#
#                                              run_data  total_power_normalized  \
# 72  [{'x': 2493, 'y': 117}, {'x': 2948, 'y': 181},...               1377093.5
#
#     max_jump         turbo
# 72  0.191973  dr650 billet
# Third quartile
#                     display_info                  name  \
# 86  {'username': 'SnakeSkinner'}  SnakeSkinner HP 16 1
#
#                 displayName  owner_id  car_id  run_id  data_type_id  \
# 86  SnakeSkinner HP (dr750)      16.0    16.0     1.0           1.0
#
#                                                  mods  \
# 86  {'displacement': '3.5', 'turbo_class': 'td04',...
#
#                                              run_data  total_power_normalized  \
# 86  [{'x': 3035, 'y': 226}, {'x': 3346, 'y': 321},...               1867320.5
#
#     max_jump  turbo
# 86  0.305466  dr750
# Maximum
#                    display_info                name          displayName  \
# 112  {'username': 'vr4usmc203'}  vr4usmc203 HP 52 2  vr4usmc203 HP (13t)
#
#      owner_id  car_id  run_id  data_type_id  \
# 112      48.0    52.0     2.0           1.0
#
#                                                   mods  \
# 112  {'fuel': 'race', 'turbo_class': 'td04', 'turbo...
#
#                                               run_data  \
# 112  [{'x': 2758, 'y': 150}, {'x': 3150, 'y': 210},...
#
#      total_power_normalized  max_jump turbo
# 112               1366323.0  0.497911   13t
# Outliers
#                    display_info                name  \
# 15   {'username': 'chansigril'}  chansigril HP 48 1
# 55     {'username': 'My923ksl'}    My923ksl HP 58 1
# 108       {'username': 'VR3.9'}       VR3.9 HP 49 1
#
#                     displayName  owner_id  car_id  run_id  data_type_id  \
# 15          chansigril HP (13t)        44      48       1             1
# 55   My923ksl HP (dr650 billet)        54      58       1             1
# 108              VR3.9 HP (13t)        45      49       1             1
#
#                                                   mods  \
# 15        {'turbo_class': 'td04', 'turbo_name': '13t'}
# 55   {'boost': '20', 'fuel': 'pump', 'turbo_class':...
# 108  {'boost': '20', 'fuel': 'e85', 'turbo_class': ...
#
#                                               run_data  \
# 15   [{'x': 2508, 'y': 104}, {'x': 2533, 'y': 143},...
# 55   [{'x': 2861, 'y': 74}, {'x': 2923, 'y': 154}, ...
# 108  [{'x': 2510, 'y': 91}, {'x': 2562, 'y': 108}, ...
#
#      total_power_normalized  max_jump         turbo
# 15                1221783.5  1.560000           13t
# 55                1367003.0  1.290323  dr650 billet
# 108               1558026.0  0.633086           13t

# %% [markdown]
# ### TD05

# %%
td05_turbos = [r['mods']['turbo_name'] for idx, r in td05.iterrows()]
td05['turbo'] = td05_turbos
td05_avg_maxlag = td05.groupby('turbo')['max_jump'].mean().reset_index().sort_values(by='max_jump')
# top 10
top = 10
print('Top 10 td05 turbos:')
display(td05_avg_maxlag.head(top))
# stats
print_df_summary(q_summary_dataframe(td05, 'max_jump'))
# Out:
# Top 10 td05 turbos:
#               turbo  max_jump
# 4            GT28RS  0.157058
# 13  frank 50 custom  0.231272
# 0               14b  0.238722
# 5           GT3076R  0.301879
# 16              t2s  0.307815
# 2             5027s  0.310863
# 3             6765r  0.312803
# 6            GT3251  0.330261
# 11         evo3 16g  0.330919
# 8            dr1000  0.344211
# Minimum
#                  display_info               name            displayName  \
# 63  {'username': 'PowerTrip'}  PowerTrip HP 43 1  PowerTrip HP (GT28RS)
#
#     owner_id  car_id  run_id  data_type_id  \
# 63      40.0    43.0     1.0           1.0
#
#                                                  mods  \
# 63  {'boost': '23', 'turbo_class': 'td05', 'turbo_...
#
#                                              run_data  total_power_normalized  \
# 63  [{'x': 3409, 'y': 207}, {'x': 3912, 'y': 286},...               1319741.5
#
#     max_jump   turbo
# 63  0.157058  GT28RS
# Maximum
#                display_info            name            displayName  owner_id  \
# 19  {'username': 'cjbyron'}  cjbyron HP 7 1  cjbyron HP (GTX4202R)       7.0
#
#     car_id  run_id  data_type_id  \
# 19     7.0     1.0           1.0
#
#                                                  mods  \
# 19  {'fuel': 'race', 'displacement': '3.5', 'turbo...
#
#                                              run_data  total_power_normalized  \
# 19  [{'x': 3131, 'y': 112}, {'x': 3437, 'y': 159},...               2280257.5
#
#     max_jump     turbo
# 19  0.559751  GTX4202R
# Outliers
#                     display_info                  name  \
# 87  {'username': 'SnakeSkinner'}  SnakeSkinner HP 36 1
#
#                 displayName  owner_id  car_id  run_id  data_type_id  \
# 87  SnakeSkinner HP (dr900)        16      36       1             1
#
#                                                  mods  \
# 87  {'boost': '28', 'fuel': 'race', 'turbo_class':...
#
#                                              run_data  total_power_normalized  \
# 87  [{'x': 4306, 'y': 205}, {'x': 4426, 'y': 290},...               1353139.5
#
#     max_jump  turbo
# 87  0.708333  dr900

# %% [markdown]
# ### TD04 top 10 vs. TD04 top 10 graph

# %%
top = 10
td04_top = td04_avg_maxlag.head(top)
td05_top = td05_avg_maxlag.head(top)
# plot the data
w = 0.5
plot.bar([n * 2 for n in range(top)], td04_top['max_jump'], width=w, label='TD04', color='Red')
plot.bar([n * 2 + 1 for n in range(top)], td05_top['max_jump'], width=w, label='TD05', color='Blue')
# title, labels, legend
plot.title('TD04 top {} vs TD05 top {}: Boost Lag'.format(top, top))
plot.ylabel('Avg. top boost lag (d(hp)/d(rpm))')
plot.xlabel('Turbo')
plot.legend()
tups = list(zip(td04_top['turbo'], td05_top['turbo']))
labels = list(chain(*tups))
plot.xticks(ticks=list(range(top*2)),labels=labels, rotation=60)
# show
plot.gcf().set_size_inches(12, 6)
plot.show()
